# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

import keras
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, Dropout

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
data_dir = 'Tesla.csv'
df = pd.read_csv(data_dir, parse_dates= True , index_col= "Date")

# %%
df.head()
# Out:
#                  Open   High        Low      Close    Volume  Adj Close
# Date
# 2010-06-29  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 2010-06-30  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2010-07-01  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 2010-07-02  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 2010-07-06  20.000000  20.00  15.830000  16.110001   6866900  16.110001

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1692 entries, 2010-06-29 to 2017-03-17
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1692 non-null   float64
#  1   High       1692 non-null   float64
#  2   Low        1692 non-null   float64
#  3   Close      1692 non-null   float64
#  4   Volume     1692 non-null   int64
#  5   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 92.5 KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.215000    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %%
plt.figure(figsize=(15, 6))
df['Open'].plot()
df['Close'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Opening & Closing Price of Tesla")
plt.legend(['Open Price', 'Close Price'])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['Volume'].plot()
plt.ylabel('Volume')
plt.xlabel(None)
plt.title("Sales Volume of Tesla")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['Adj Close'].pct_change().hist(bins=50)
plt.ylabel('Daily Return')
plt.title(f'Tesla Dialy Return')
plt.tight_layout()
plt.show()

# %%
dataset = df["Close"]
dataset = pd.DataFrame(dataset)

data = dataset.values

data.shape
# Out:
# (1692, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data).reshape(-1, 1))

# %%
train_size = int(len(data)*.75)
test_size = len(data) - train_size

print("Train Size :",train_size,"Test Size :",test_size)

train_data = scaled_data[ :train_size , 0:1 ]
test_data = scaled_data[ train_size-60: , 0:1 ]
# Out:
# Train Size : 1269 Test Size : 423

# %%
train_data.shape, test_data.shape
# Out:
# ((1269, 1), (483, 1))

# %%
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %%
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
x_train.shape , y_train.shape
# Out:
# ((1209, 60, 1), (1209,))

# %%
model = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], 1)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(1)
])

model.compile(optimizer= 'adam', loss= 'mse' , metrics= "mean_absolute_error")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  lstm_1 (LSTM)               (None, 64)                29440
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 42,465
# Trainable params: 42,465
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks = [EarlyStopping(monitor= 'loss', patience= 10 , restore_best_weights= True)]
history = model.fit(x_train, y_train, epochs= 100, batch_size= 32 , callbacks= callbacks )
# Out:
# Epoch 1/100
# 38/38 [==============================] - 10s 53ms/step - loss: 0.0301 - mean_absolute_error: 0.1077
# Epoch 2/100
# 38/38 [==============================] - 2s 50ms/step - loss: 0.0014 - mean_absolute_error: 0.0257
# Epoch 3/100
# 38/38 [==============================] - 2s 49ms/step - loss: 0.0012 - mean_absolute_error: 0.0216
# Epoch 4/100
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0012 - mean_absolute_error: 0.0215
# Epoch 5/100
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0011 - mean_absolute_error: 0.0207
# Epoch 6/100
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0010 - mean_absolute_error: 0.0203
# Epoch 7/100
# 38/38 [==============================] - 2s 52ms/step - loss: 9.7107e-04 - mean_absolute_error: 0.0199
# Epoch 8/100
# 38/38 [==============================] - 2s 53ms/step - loss: 9.3841e-04 - mean_absolute_error: 0.0196
# Epoch 9/100
# 38/38 [==============================] - 2s 56ms/step - loss: 8.8581e-04 - mean_absolute_error: 0.0189
# Epoch 10/100
# 38/38 [==============================] - 2s 53ms/step - loss: 8.0968e-04 - mean_absolute_error: 0.0182
# Epoch 11/100
# 38/38 [==============================] - 2s 53ms/step - loss: 8.9872e-04 - mean_absolute_error: 0.0191
# Epoch 12/100
# 38/38 [==============================] - 2s 52ms/step - loss: 8.9125e-04 - mean_absolute_error: 0.0194
# Epoch 13/100
# 38/38 [==============================] - 2s 53ms/step - loss: 8.3795e-04 - mean_absolute_error: 0.0187
# Epoch 14/100
# 38/38 [==============================] - 2s 52ms/step - loss: 7.4980e-04 - mean_absolute_error: 0.0176
# Epoch 15/100
# 38/38 [==============================] - 2s 52ms/step - loss: 8.8663e-04 - mean_absolute_error: 0.0191
# Epoch 16/100
# 38/38 [==============================] - 2s 52ms/step - loss: 8.4265e-04 - mean_absolute_error: 0.0189
# Epoch 17/100
# 38/38 [==============================] - 2s 57ms/step - loss: 7.1209e-04 - mean_absolute_error: 0.0170
# Epoch 18/100
# 38/38 [==============================] - 2s 55ms/step - loss: 7.5140e-04 - mean_absolute_error: 0.0174
# Epoch 19/100
# 38/38 [==============================] - 2s 52ms/step - loss: 7.5491e-04 - mean_absolute_error: 0.0179
# Epoch 20/100
# 38/38 [==============================] - 2s 52ms/step - loss: 6.8573e-04 - mean_absolute_error: 0.0168
# Epoch 21/100
# 38/38 [==============================] - 2s 54ms/step - loss: 6.2801e-04 - mean_absolute_error: 0.0162
# Epoch 22/100
# 38/38 [==============================] - 2s 53ms/step - loss: 6.2456e-04 - mean_absolute_error: 0.0161
# Epoch 23/100
# 38/38 [==============================] - 2s 54ms/step - loss: 6.2322e-04 - mean_absolute_error: 0.0158
# Epoch 24/100
# 38/38 [==============================] - 2s 53ms/step - loss: 6.2233e-04 - mean_absolute_error: 0.0158
# Epoch 25/100
# 38/38 [==============================] - 2s 58ms/step - loss: 6.5137e-04 - mean_absolute_error: 0.0166
# Epoch 26/100
# 38/38 [==============================] - 2s 54ms/step - loss: 5.7437e-04 - mean_absolute_error: 0.0151
# Epoch 27/100
# 38/38 [==============================] - 2s 55ms/step - loss: 6.1625e-04 - mean_absolute_error: 0.0160
# Epoch 28/100
# 38/38 [==============================] - 2s 52ms/step - loss: 5.8116e-04 - mean_absolute_error: 0.0153
# Epoch 29/100
# 38/38 [==============================] - 2s 59ms/step - loss: 5.6769e-04 - mean_absolute_error: 0.0151
# Epoch 30/100
# 38/38 [==============================] - 2s 52ms/step - loss: 5.3243e-04 - mean_absolute_error: 0.0147
# Epoch 31/100
# 38/38 [==============================] - 2s 54ms/step - loss: 5.1837e-04 - mean_absolute_error: 0.0142
# Epoch 32/100
# 38/38 [==============================] - 2s 57ms/step - loss: 5.1408e-04 - mean_absolute_error: 0.0142
# Epoch 33/100
# 38/38 [==============================] - 2s 54ms/step - loss: 4.8810e-04 - mean_absolute_error: 0.0138
# Epoch 34/100
# 38/38 [==============================] - 2s 53ms/step - loss: 5.9107e-04 - mean_absolute_error: 0.0152
# Epoch 35/100
# 38/38 [==============================] - 2s 52ms/step - loss: 6.0958e-04 - mean_absolute_error: 0.0158
# Epoch 36/100
# 38/38 [==============================] - 2s 52ms/step - loss: 5.6719e-04 - mean_absolute_error: 0.0153
# Epoch 37/100
# 38/38 [==============================] - 2s 53ms/step - loss: 4.3555e-04 - mean_absolute_error: 0.0129
# Epoch 38/100
# 38/38 [==============================] - 2s 52ms/step - loss: 4.4941e-04 - mean_absolute_error: 0.0131
# Epoch 39/100
# 38/38 [==============================] - 2s 54ms/step - loss: 5.0246e-04 - mean_absolute_error: 0.0141
# Epoch 40/100
# 38/38 [==============================] - 2s 56ms/step - loss: 5.0231e-04 - mean_absolute_error: 0.0140
# Epoch 41/100
# 38/38 [==============================] - 2s 54ms/step - loss: 4.6767e-04 - mean_absolute_error: 0.0136
# Epoch 42/100
# 38/38 [==============================] - 2s 52ms/step - loss: 4.4535e-04 - mean_absolute_error: 0.0132
# Epoch 43/100
# 38/38 [==============================] - 2s 53ms/step - loss: 5.2429e-04 - mean_absolute_error: 0.0150
# Epoch 44/100
# 38/38 [==============================] - 2s 52ms/step - loss: 3.9538e-04 - mean_absolute_error: 0.0124
# Epoch 45/100
# 38/38 [==============================] - 2s 52ms/step - loss: 3.9513e-04 - mean_absolute_error: 0.0122
# Epoch 46/100
# 38/38 [==============================] - 2s 54ms/step - loss: 4.3254e-04 - mean_absolute_error: 0.0133
# Epoch 47/100
# 38/38 [==============================] - 2s 52ms/step - loss: 5.4897e-04 - mean_absolute_error: 0.0152
# Epoch 48/100
# 38/38 [==============================] - 2s 58ms/step - loss: 5.8824e-04 - mean_absolute_error: 0.0158
# Epoch 49/100
# 38/38 [==============================] - 2s 54ms/step - loss: 3.8575e-04 - mean_absolute_error: 0.0123
# Epoch 50/100
# 38/38 [==============================] - 2s 52ms/step - loss: 4.7838e-04 - mean_absolute_error: 0.0138
# Epoch 51/100
# 38/38 [==============================] - 2s 51ms/step - loss: 3.8025e-04 - mean_absolute_error: 0.0119
# Epoch 52/100
# 38/38 [==============================] - 2s 52ms/step - loss: 4.4584e-04 - mean_absolute_error: 0.0130
# Epoch 53/100
# 38/38 [==============================] - 2s 53ms/step - loss: 4.0479e-04 - mean_absolute_error: 0.0127
# Epoch 54/100
# 38/38 [==============================] - 2s 51ms/step - loss: 4.7731e-04 - mean_absolute_error: 0.0142
# Epoch 55/100
# 38/38 [==============================] - 2s 53ms/step - loss: 4.1982e-04 - mean_absolute_error: 0.0129
# Epoch 56/100
# 38/38 [==============================] - 2s 57ms/step - loss: 4.0143e-04 - mean_absolute_error: 0.0127
# Epoch 57/100
# 38/38 [==============================] - 2s 56ms/step - loss: 3.4957e-04 - mean_absolute_error: 0.0115
# Epoch 58/100
# 38/38 [==============================] - 2s 52ms/step - loss: 3.4504e-04 - mean_absolute_error: 0.0114
# Epoch 59/100
# 38/38 [==============================] - 2s 52ms/step - loss: 4.4381e-04 - mean_absolute_error: 0.0134
# Epoch 60/100
# 38/38 [==============================] - 2s 54ms/step - loss: 3.9309e-04 - mean_absolute_error: 0.0127
# Epoch 61/100
# 38/38 [==============================] - 2s 53ms/step - loss: 3.3807e-04 - mean_absolute_error: 0.0114
# Epoch 62/100
# 38/38 [==============================] - 2s 53ms/step - loss: 3.6664e-04 - mean_absolute_error: 0.0123
# Epoch 63/100
# 38/38 [==============================] - 2s 52ms/step - loss: 4.0958e-04 - mean_absolute_error: 0.0127
# Epoch 64/100
# 38/38 [==============================] - 2s 56ms/step - loss: 3.8045e-04 - mean_absolute_error: 0.0127
# Epoch 65/100
# 38/38 [==============================] - 2s 54ms/step - loss: 4.2832e-04 - mean_absolute_error: 0.0132
# Epoch 66/100
# 38/38 [==============================] - 2s 53ms/step - loss: 3.3933e-04 - mean_absolute_error: 0.0114
# Epoch 67/100
# 38/38 [==============================] - 2s 52ms/step - loss: 3.1718e-04 - mean_absolute_error: 0.0108
# Epoch 68/100
# 38/38 [==============================] - 2s 52ms/step - loss: 3.2307e-04 - mean_absolute_error: 0.0114
# Epoch 69/100
# 38/38 [==============================] - 2s 52ms/step - loss: 3.2380e-04 - mean_absolute_error: 0.0111
# Epoch 70/100
# 38/38 [==============================] - 2s 53ms/step - loss: 3.6996e-04 - mean_absolute_error: 0.0123
# Epoch 71/100
# 38/38 [==============================] - 2s 53ms/step - loss: 3.5127e-04 - mean_absolute_error: 0.0119
# Epoch 72/100
# 38/38 [==============================] - 2s 57ms/step - loss: 3.2603e-04 - mean_absolute_error: 0.0111
# Epoch 73/100
# 38/38 [==============================] - 2s 53ms/step - loss: 3.0908e-04 - mean_absolute_error: 0.0108
# Epoch 74/100
# 38/38 [==============================] - 2s 54ms/step - loss: 3.0222e-04 - mean_absolute_error: 0.0106
# Epoch 75/100
# 38/38 [==============================] - 2s 52ms/step - loss: 3.0181e-04 - mean_absolute_error: 0.0106
# Epoch 76/100
# 38/38 [==============================] - 2s 56ms/step - loss: 2.9116e-04 - mean_absolute_error: 0.0104
# Epoch 77/100
# 38/38 [==============================] - 2s 53ms/step - loss: 2.9691e-04 - mean_absolute_error: 0.0107
# Epoch 78/100
# 38/38 [==============================] - 2s 53ms/step - loss: 3.2924e-04 - mean_absolute_error: 0.0114
# Epoch 79/100
# 38/38 [==============================] - 2s 54ms/step - loss: 3.3255e-04 - mean_absolute_error: 0.0114
# Epoch 80/100
# 38/38 [==============================] - 2s 59ms/step - loss: 3.4272e-04 - mean_absolute_error: 0.0116
# Epoch 81/100
# 38/38 [==============================] - 2s 54ms/step - loss: 3.7116e-04 - mean_absolute_error: 0.0124
# Epoch 82/100
# 38/38 [==============================] - 2s 53ms/step - loss: 2.6639e-04 - mean_absolute_error: 0.0097
# Epoch 83/100
# 38/38 [==============================] - 2s 52ms/step - loss: 2.9288e-04 - mean_absolute_error: 0.0105
# Epoch 84/100
# 38/38 [==============================] - 2s 52ms/step - loss: 2.5838e-04 - mean_absolute_error: 0.0097
# Epoch 85/100
# 38/38 [==============================] - 2s 52ms/step - loss: 2.7777e-04 - mean_absolute_error: 0.0104
# Epoch 86/100
# 38/38 [==============================] - 2s 52ms/step - loss: 2.6274e-04 - mean_absolute_error: 0.0098
# Epoch 87/100
# 38/38 [==============================] - 2s 54ms/step - loss: 4.1264e-04 - mean_absolute_error: 0.0132
# Epoch 88/100
# 38/38 [==============================] - 2s 56ms/step - loss: 2.9647e-04 - mean_absolute_error: 0.0109
# Epoch 89/100
# 38/38 [==============================] - 2s 52ms/step - loss: 3.0819e-04 - mean_absolute_error: 0.0109
# Epoch 90/100
# 38/38 [==============================] - 2s 52ms/step - loss: 2.6420e-04 - mean_absolute_error: 0.0100
# Epoch 91/100
# 38/38 [==============================] - 2s 52ms/step - loss: 3.3980e-04 - mean_absolute_error: 0.0123
# Epoch 92/100
# 38/38 [==============================] - 2s 54ms/step - loss: 3.0739e-04 - mean_absolute_error: 0.0111
# Epoch 93/100
# 38/38 [==============================] - 2s 53ms/step - loss: 2.7854e-04 - mean_absolute_error: 0.0106
# Epoch 94/100
# 38/38 [==============================] - 2s 53ms/step - loss: 2.5989e-04 - mean_absolute_error: 0.0100

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
x_test = []
y_test = []

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
x_test.shape , y_test.shape
# Out:
# ((423, 60, 1), (423,))

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# 14/14 [==============================] - 2s 22ms/step
# (423, 1)

# %%
y_test = scaler.inverse_transform([y_test])

RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 1.99

# %%
train = dataset.iloc[:train_size , 0:1]
test = dataset.iloc[train_size: , 0:1]
test['Predictions'] = predictions

plt.figure(figsize= (16, 6))
plt.title('Tesla Close Stock Price Prediction', fontsize= 18)
plt.xlabel('Date', fontsize= 18)
plt.ylabel('Close Price', fontsize= 18)
plt.plot(train['Close'], linewidth= 3)
plt.plot(test['Close'], linewidth= 3)
plt.plot(test["Predictions"], linewidth= 3)
plt.legend(['Train', 'Test', 'Predictions'])
